# %%
import sys
sys.path.append('../src')

# %%
import Sorteoamigo

# %%
participantes = ["Ana", "Pedro", "Lucía", "Mateo", "Sofía"]
pares = Sorteoamigo.sorteo_amigo_invisible(participantes)

print("Sorteo de amigo invisible:")
for dador, receptor in pares:
    print(f"{dador} → {receptor}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 participantes = ["Ana", "Pedro", "Lucía", "Mateo", "Sofía"]
# ----> 2 pares = sorteo_amigo_invisible(participantes)
#       3
#       4 print("Sorteo de amigo invisible:")
#       5 for dador, receptor in pares:
#
# NameError: name 'sorteo_amigo_invisible' is not defined
