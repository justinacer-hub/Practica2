# %%
import sys
sys.path.append('../src')

# %%
import Duracionplaylist

# %%
playlist = [
{"title": "Bohemian Rhapsody", "duration": "5:55"},
{"title": "Hotel California", "duration": "6:30"},
{"title": "Stairway to Heaven", "duration": "8:02"},
{"title": "Imagine", "duration": "3:07"},
{"title": "Smells Like Teen Spirit", "duration": "5:01"},
{"title": "Billie Jean", "duration": "4:54"},
{"title": "Hey Jude", "duration": "7:11"},
{"title": "Like a Rolling Stone", "duration": "6:13"},
]

# %%
Duracionplaylist.duracion_playlist(playlist)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 Duracionplaylist.duracion_playlist(playlist)
#
# File c:\Users\Usuario\Desktop\Python-Facultad\Practica2\notebooks\../src\Duracionplaylist.py:6, in duracion_playlist(playlist)
#       3 duraciones = []
#       5 for canciones in playlist:
# ----> 6     partes = cancion["duration"].split(":") # separo m y s
#       7     minutos = int(partes[0])
#       8     segundos = int(partes[1])
#
# NameError: name 'cancion' is not defined
