# %%
import sys
sys.path.append('../src')

# %%
import importlib
import Costoenvio
importlib.reload(Costoenvio)
# Out:
# <module 'Costoenvio' from 'c:\\Users\\Usuario\\Desktop\\Python-Facultad\\Practica2\\notebooks\\../src\\Costoenvio.py'>

# %%
print(Costoenvio.costo_envio(3.5, "regional"))
print(Costoenvio.costo_envio(0.5, "internacional"))
# Out:
# Ingrese el peso del paquete (kg): 3.5
# Ingrese la zona de destino (local/regional/nacional): regional
# Costo de envío: $2500
# Zona no válida. Las zonas disponibles son: local, regional, nacional.
